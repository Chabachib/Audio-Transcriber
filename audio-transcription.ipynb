# %%
# !pip install faster-whisper -q
# !pip install pytubefix -q

# %%
# !npm install -g youtube-po-token-generator
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏npm warn deprecated boolean@3.2.0: Package no longer supported. Contact Support at https://www.npmjs.com/support for more info.
# ⠏⠋⠙⠹
# added 63 packages in 3s
# ⠹
# ⠹10 packages are looking for funding
# ⠹  run `npm fund` for details
# ⠹npm notice
# npm notice New major version of npm available! 10.8.2 -> 11.4.1
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v11.4.1
# npm notice To update run: npm install -g npm@11.4.1
# npm notice
# ⠹

# %%
# !youtube-po-token-generator
# Out:
# {"visitorData":"CgtZTmVaS3RMeTVzTSj27OHBBjIKCgJUVxIEGgAgbA%3D%3D","poToken":"MnTrBqi9Y6CUmes-UFKnBOa6oe3m1xuF6TTyhvVQ_rF0vJOQIJs9W2LoM-V6Fc88SQp-duKmEuKdDTQcmwTZOiNcLLiwh3mulaTYrGgHk1NXdyALXy9nSzp2QOkuC1v4HwTq_ZWv0N2xry-tkDCv-qmwOeM8sQ=="}

# %% [markdown]
# ## Download the songs from YouTube

# %%
from pytubefix import YouTube
from pytubefix.cli import on_progress

# %%
def audio_download(urls):
    download_path = "/kaggle/working/"
    for url in urls:
        yt = YouTube(url, on_progress_callback=on_progress, use_po_token=True)
        ys = yt.streams.get_audio_only()
        ys.download(output_path=download_path)

# %%
songs_list = []

while True:
    url = input("Enter a YouTube URL (or 'done' to finish) :")
    if url == 'done':
        break
    songs_list.append(url)
# Out:
# Enter a YouTube URL (or 'done' to finish) : https://www.youtube.com/watch?v=YW66sMK1Rf0
# Enter a YouTube URL (or 'done' to finish) : done

# %%
audio_download(songs_list)
# Out:
# You can use the tool: https://github.com/YunzheZJU/youtube-po-token-generator, to get the token
# Enter with your visitorData:  CgtZTmVaS3RMeTVzTSj27OHBBjIKCgJUVxIEGgAgbA%3D%3D
# Enter with your po_token:  MnTrBqi9Y6CUmes-UFKnBOa6oe3m1xuF6TTyhvVQ_rF0vJOQIJs9W2LoM-V6Fc88SQp-duKmEuKdDTQcmwTZOiNcLLiwh3mulaTYrGgHk1NXdyALXy9nSzp2QOkuC1v4HwTq_ZWv0N2xry-tkDCv-qmwOeM8sQ==
#  ↳ |███████████████████████████████████████████████████████| 100.0%

# %% [markdown]
# ## Transcribe the songs

# %%
import os
from faster_whisper import WhisperModel

# %%
model_size = "large-v3"

model = WhisperModel(model_size, device="cuda", compute_type="float16") # Use Settings -> Accelerator -> GPU T4 x2
# Out:
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# vocabulary.json:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.39k [00:00<?, ?B/s]

# %%
folder_path = "/kaggle/working/"
folder_list = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith(('.mp3', '.m4a', '.wav'))]

# %%
for song in folder_list:
    segments, info = model.transcribe(song, beam_size=5)
    song_basename = os.path.basename(song)

    print("Detected language '%s' with probability %f" % (info.language, info.language_probability))

    for segment in segments:
        with open(song_basename + ".txt", "a") as file:
            file.write("[%.2fs -> %.2fs] %s\n" % (segment.start, segment.end, segment.text))
# Out:
# Detected language 'en' with probability 0.937012
